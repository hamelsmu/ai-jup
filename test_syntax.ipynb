# %%
import random

# %%
a = random.randint(0, 100)

# %% [markdown]
# What is the value of $`a`?

# %% [markdown]
# The value of 17 is simply 17.
#
# In your code, the variable `a` has been assigned the value 17 (which was randomly generated between 0 and 100). So `a = 17`.
#
# If you're asking about properties or characteristics of the number 17:
# - It's a prime number
# - It's an odd number
# - It's between 16 and 18
# - In binary, it's 10001
# - In hexadecimal, it's 11
#
# Is there something specific about the number 17 you'd like to know?

# %%
a
# Out:
# 17
